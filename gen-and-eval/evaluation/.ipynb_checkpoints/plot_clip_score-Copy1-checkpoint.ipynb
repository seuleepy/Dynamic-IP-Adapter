# %% [markdown]
# Load clip score and plot

# %%
import json
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
# load json file

image_score_json = "./sd_v15/clip_image_score_vitl14.json"
text_score_json = "./sd_v15/clip_text_score_vitl14.json"

with open(image_score_json, 'r') as f:
    image_score = json.load(f)
with open(text_score_json, 'r') as f:
    text_score = json.load(f)

# %% [markdown]
# 각 모델별로 image score, text score

# %%
# summation per model

MODEL_LIST = [
        "constant_05",
        "constant_10",
        "linear",
        "relu_100",
        "relu_500",
        "relu_900",
        "sigmoid",
        "sine",
    ]
model_image_scores = defaultdict(float)
model_text_scores = defaultdict(float)

for key, score in image_score.items():
    for model in MODEL_LIST:
        if key.startswith(model):
            model_image_scores[model] += score

for key, score in text_score.items():
    for model in MODEL_LIST:
        if key.startswith(model):
            model_text_scores[model] += score

for key in model_image_scores:
    model_image_scores[key] /= 30
    model_text_scores[key] /= 30

# %%
with open("./sd_v15/model_image_scores.json", "w") as f:
    json.dump(model_image_scores, f, indent=4)
with open("./sd_v15/model_text_scores.json", "w") as f:
    json.dump(model_text_scores, f, indent=4)

# %%
models = list(model_image_scores.keys())
image_scores = list(model_scores.values())

plt.figure(figsize=(10, 6))
plt.plot(models, image_scores, marker='o', linestyle='-',color='skyblue', label='all')
plt.xlabel('Model')
plt.ylabel('Score')
plt.legend()
plt.title("CLIP Image Score")
plt.tight_layout()
plt.show()

# %%
models = list(model_text_scores.keys())
text_scores = list(model_text_scores.values())

plt.figure(figsize=(10, 6))
plt.plot(models, text_scores, marker='o', linestyle='-',color='skyblue', label='all')
plt.xlabel('Model')
plt.ylabel('Score')
plt.legend()
plt.title("CLIP Text Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# subject, model에 대해 image score, text score

# %%
# comparison per target

from constant import TARGET2CLASS_MAPPING

MODEL_LIST = [
        "constant_05",
        "constant_10",
        "linear",
        "relu_100",
        "relu_500",
        "relu_900",
        "sigmoid",
        "sine",
    ]

target_image_dict = {}
target_text_dict = {}

for target in TARGET2CLASS_MAPPING:
    target_dict = {}
    for key, score in image_score.items():
        if key.endswith(target):
            model = key.removesuffix(f"_{target}")
            target_dict[model] = score
    target_image_dict[target] = target_dict
    with open(f"./sd_v15/{target}_image_scores.json", "w") as f:
        json.dump(target_dict, f, indent=4)
    
for target in TARGET2CLASS_MAPPING:
    target_dict = {}
    for key, score in text_score.items():
        if key.endswith(target):
            model = key.removesuffix(f"_{target}")
            target_dict[model] = score
    target_text_dict[target] = target_dict
    with open(f"./sd_v15/{target}_text_scores.json", "w") as f:
        json.dump(target_dict, f, indent=4)

# %%
plt.figure(figsize=(10, 6))
for subject, scores in target_image_dict.items():
    model_scores = [scores[model] for model in MODEL_LIST]
    plt.plot(MODEL_LIST, model_scores, marker='o', label=subject)

plt.xlabel("Model")
plt.ylabel("Score")
plt.title("CLIP Image Score")
plt.legend()
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(10, 6))
for subject, scores in target_text_dict.items():
    model_scores = [scores[model] for model in MODEL_LIST]
    plt.plot(MODEL_LIST, model_scores, marker='o', label=subject)

plt.xlabel("Model")
plt.ylabel("Score")
plt.title("CLIP Text Score")
plt.legend()
plt.tight_layout()

plt.show()

# %% [markdown]
# subject (live vs object) 비교

# %%
target_image_dict
# Out:
# {'backpack': {'constant_05': 0.84734375,
#   'constant_10': 0.89640625,
#   'linear': 0.81828125,
#   'relu_100': 0.7175,
#   'relu_500': 0.7440625,
#   'relu_900': 0.79140625,
#   'sigmoid': 0.783125,
#   'sine': 0.83609375},
#  'backpack_dog': {'constant_05': 0.68140625,
#   'constant_10': 0.77046875,
#   'linear': 0.62109375,
#   'relu_100': 0.536015625,
#   'relu_500': 0.55359375,
#   'relu_900': 0.60125,
#   'sigmoid': 0.595,
#   'sine': 0.66453125},
#  'bear_plushie': {'constant_05': 0.74875,
#   'constant_10': 0.76515625,
#   'linear': 0.69265625,
#   'relu_100': 0.556796875,
#   'relu_500': 0.588125,
#   'relu_900': 0.65984375,
#   'sigmoid': 0.65734375,
#   'sine': 0.72484375},
#  'berry_bowl': {'constant_05': 0.810625,
#   'constant_10': 0.88015625,
#   'linear': 0.73546875,
#   'relu_100': 0.639609375,
#   'relu_500': 0.6565625,
#   'relu_900': 0.7065625,
#   'sigmoid': 0.70046875,
#   'sine': 0.78203125},
#  'can': {'constant_05': 0.589140625,
#   'constant_10': 0.65671875,
#   'linear': 0.548046875,
#   'relu_100': 0.448125,
#   'relu_500': 0.471875,
#   'relu_900': 0.53140625,
#   'sigmoid': 0.53109375,
#   'sine': 0.57359375},
#  'candle': {'constant_05': 0.647734375,
#   'constant_10': 0.6984375,
#   'linear': 0.57953125,
#   'relu_100': 0.50796875,
#   'relu_500': 0.519375,
#   'relu_900': 0.564296875,
#   'sigmoid': 0.5571875,
#   'sine': 0.614765625},
#  'cat': {'constant_05': 0.8971875,
#   'constant_10': 0.92984375,
#   'linear': 0.8075,
#   'relu_100': 0.7059375,
#   'relu_500': 0.7328125,
#   'relu_900': 0.78828125,
#   'sigmoid': 0.779375,
#   'sine': 0.8471875},
#  'cat2': {'constant_05': 0.85484375,
#   'constant_10': 0.87953125,
#   'linear': 0.7790625,
#   'relu_100': 0.705,
#   'relu_500': 0.7175,
#   'relu_900': 0.75625,
#   'sigmoid': 0.7515625,
#   'sine': 0.80265625},
#  'clock': {'constant_05': 0.9328125,
#   'constant_10': 0.9546875,
#   'linear': 0.878125,
#   'relu_100': 0.7840625,
#   'relu_500': 0.80109375,
#   'relu_900': 0.8503125,
#   'sigmoid': 0.84546875,
#   'sine': 0.90578125},
#  'colorful_sneaker': {'constant_05': 0.7590625,
#   'constant_10': 0.806875,
#   'linear': 0.68984375,
#   'relu_100': 0.57984375,
#   'relu_500': 0.608203125,
#   'relu_900': 0.6634375,
#   'sigmoid': 0.66140625,
#   'sine': 0.72171875},
#  'dog': {'constant_05_backpack': 0.68140625,
#   'constant_10_backpack': 0.77046875,
#   'linear_backpack': 0.62109375,
#   'relu_100_backpack': 0.536015625,
#   'relu_500_backpack': 0.55359375,
#   'relu_900_backpack': 0.60125,
#   'sigmoid_backpack': 0.595,
#   'sine_backpack': 0.66453125,
#   'constant_05': 0.86234375,
#   'constant_10': 0.915,
#   'linear': 0.78078125,
#   'relu_100': 0.69140625,
#   'relu_500': 0.715625,
#   'relu_900': 0.76046875,
#   'sigmoid': 0.75359375,
#   'sine': 0.79984375},
#  'dog2': {'constant_05': 0.89953125,
#   'constant_10': 0.94421875,
#   'linear': 0.79625,
#   'relu_100': 0.6821875,
#   'relu_500': 0.709375,
#   'relu_900': 0.77265625,
#   'sigmoid': 0.76625,
#   'sine': 0.8309375},
#  'dog3': {'constant_05': 0.85328125,
#   'constant_10': 0.88703125,
#   'linear': 0.77765625,
#   'relu_100': 0.66828125,
#   'relu_500': 0.69640625,
#   'relu_900': 0.75265625,
#   'sigmoid': 0.7459375,
#   'sine': 0.80859375},
#  'dog5': {'constant_05': 0.92484375,
#   'constant_10': 0.955,
#   'linear': 0.7934375,
#   'relu_100': 0.68640625,
#   'relu_500': 0.70546875,
#   'relu_900': 0.76359375,
#   'sigmoid': 0.76,
#   'sine': 0.83359375},
#  'dog6': {'constant_05': 0.80640625,
#   'constant_10': 0.83046875,
#   'linear': 0.755625,
#   'relu_100': 0.68171875,
#   'relu_500': 0.70578125,
#   'relu_900': 0.7425,
#   'sigmoid': 0.7415625,
#   'sine': 0.774375},
#  'dog7': {'constant_05': 0.86546875,
#   'constant_10': 0.919375,
#   'linear': 0.783125,
#   'relu_100': 0.67640625,
#   'relu_500': 0.7053125,
#   'relu_900': 0.7625,
#   'sigmoid': 0.75859375,
#   'sine': 0.8121875},
#  'dog8': {'constant_05': 0.88015625,
#   'constant_10': 0.90953125,
#   'linear': 0.79578125,
#   'relu_100': 0.67375,
#   'relu_500': 0.70625,
#   'relu_900': 0.76546875,
#   'sigmoid': 0.7621875,
#   'sine': 0.82703125},
#  'duck_toy': {'constant_05': 0.8375,
#   'constant_10': 0.90609375,
#   'linear': 0.7428125,
#   'relu_100': 0.67515625,
#   'relu_500': 0.6934375,
#   'relu_900': 0.726875,
#   'sigmoid': 0.7234375,
#   'sine': 0.7703125},
#  'fancy_boot': {'constant_05': 0.77703125,
#   'constant_10': 0.8371875,
#   'linear': 0.653203125,
#   'relu_100': 0.551953125,
#   'relu_500': 0.5709375,
#   'relu_900': 0.62515625,
#   'sigmoid': 0.621015625,
#   'sine': 0.69359375},
#  'grey_sloth_plushie': {'constant_05': 0.781875,
#   'constant_10': 0.80328125,
#   'linear': 0.7209375,
#   'relu_100': 0.65484375,
#   'relu_500': 0.6709375,
#   'relu_900': 0.701875,
#   'sigmoid': 0.69796875,
#   'sine': 0.74671875},
#  'monster_toy': {'constant_05': 0.71921875,
#   'constant_10': 0.79421875,
#   'linear': 0.621171875,
#   'relu_100': 0.47328125,
#   'relu_500': 0.503828125,
#   'relu_900': 0.59015625,
#   'sigmoid': 0.582265625,
#   'sine': 0.6709375},
#  'pink_sunglasses': {'constant_05': 0.8853125,
#   'constant_10': 0.93375,
#   'linear': 0.80390625,
#   'relu_100': 0.69015625,
#   'relu_500': 0.704375,
#   'relu_900': 0.76390625,
#   'sigmoid': 0.7559375,
#   'sine': 0.84921875},
#  'poop_emoji': {'constant_05': 0.7775,
#   'constant_10': 0.873125,
#   'linear': 0.61921875,
#   'relu_100': 0.543984375,
#   'relu_500': 0.556484375,
#   'relu_900': 0.5978125,
#   'sigmoid': 0.593359375,
#   'sine': 0.67953125},
#  'rc_car': {'constant_05': 0.740625,
#   'constant_10': 0.7803125,
#   'linear': 0.66359375,
#   'relu_100': 0.558671875,
#   'relu_500': 0.580546875,
#   'relu_900': 0.636953125,
#   'sigmoid': 0.635859375,
#   'sine': 0.69515625},
#  'red_cartoon': {'constant_05': 0.74125,
#   'constant_10': 0.78359375,
#   'linear': 0.620234375,
#   'relu_100': 0.4884375,
#   'relu_500': 0.519765625,
#   'relu_900': 0.597421875,
#   'sigmoid': 0.598359375,
#   'sine': 0.66796875},
#  'robot_toy': {'constant_05': 0.8109375,
#   'constant_10': 0.835625,
#   'linear': 0.62828125,
#   'relu_100': 0.5025,
#   'relu_500': 0.51734375,
#   'relu_900': 0.590546875,
#   'sigmoid': 0.580546875,
#   'sine': 0.71640625},
#  'shiny_sneaker': {'constant_05': 0.6990625,
#   'constant_10': 0.7578125,
#   'linear': 0.628515625,
#   'relu_100': 0.471171875,
#   'relu_500': 0.498515625,
#   'relu_900': 0.586953125,
#   'sigmoid': 0.58078125,
#   'sine': 0.674375},
#  'teapot': {'constant_05': 0.93453125,
#   'constant_10': 0.9403125,
#   'linear': 0.8915625,
#   'relu_100': 0.8046875,
#   'relu_500': 0.82203125,
#   'relu_900': 0.865,
#   'sigmoid': 0.8640625,
#   'sine': 0.91875},
#  'vase': {'constant_05': 0.85765625,
#   'constant_10': 0.865,
#   'linear': 0.7890625,
#   'relu_100': 0.6834375,
#   'relu_500': 0.71515625,
#   'relu_900': 0.76859375,
#   'sigmoid': 0.769375,
#   'sine': 0.8140625},
#  'wolf_plushie': {'constant_05': 0.72453125,
#   'constant_10': 0.76796875,
#   'linear': 0.628359375,
#   'relu_100': 0.49734375,
#   'relu_500': 0.525390625,
#   'relu_900': 0.60578125,
#   'sigmoid': 0.59625,
#   'sine': 0.670625}}

# %%
from constant import CLASS2OBJECT_MAPPING

live_image_dict = defaultdict(float)
object_image_dict = defaultdict(float)
live_text_dict = defaultdict(float)
object_text_dict = defaultdict(float)

live_len = 0
object_len = 0
for target, class_type in TARGET2CLASS_MAPPING.items():
    if CLASS2OBJECT_MAPPING[class_type]:
        image_dict = object_image_dict
        text_dict = object_text_dict
        object_len += 1
    else:
        image_dict = live_image_dict
        text_dict = live_text_dict
        live_len += 1
    for model in MODEL_LIST:
        image_dict[model] += target_image_dict[target][model]
        text_dict[model] += target_text_dict[target][model]

for model in MODEL_LIST:
    live_image_dict[model] /= live_len
    object_image_dict[model] /= object_len
    live_text_dict[model] /= live_len
    object_text_dict[model] /= object_len

# %%
plt.figure(figsize=(10, 6))
live_image_scores = [live_image_dict[model] for model in MODEL_LIST]
object_image_scores = [object_image_dict[model] for model in MODEL_LIST]
plt.plot(MODEL_LIST, live_image_scores, marker='o', label="live")
plt.plot(MODEL_LIST, object_image_scores, marker='o', label="object")
plt.xlabel("Model")
plt.ylabel("Score")
plt.title("CLIP Image Score")
plt.legend()
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(10, 6))
live_image_scores = [live_text_dict[model] for model in MODEL_LIST]
object_image_scores = [object_text_dict[model] for model in MODEL_LIST]
plt.plot(MODEL_LIST, live_image_scores, marker='o', label="live")
plt.plot(MODEL_LIST, object_image_scores, marker='o', label="object")
plt.xlabel("Model")
plt.ylabel("Score")
plt.title("CLIP Text Score")
plt.legend()
plt.tight_layout()

plt.show()
